# %%
from constant_velocity_gradient_1D import run_test
run_test()
# Out:
# npoints None
# nrays None
# nboundary None
# nspecs None
# nlspecs None
# <bound method Boundary.__legacy_convert_boundaryType of <magrittetorch.model.geometry.boundary.Boundary object at 0x7f7578463990>> spherical_symmetry
# spherical_symmetry <bound method Boundary.__legacy_convert_boundaryType of <magrittetorch.model.geometry.boundary.Boundary object at 0x7f7578463990>>
# spherical_symmetry
# <bound method Geometry.__legacy_convert_geometryType of <magrittetorch.model.geometry.geometry.Geometry object at 0x7f75784639d0>> spherical_symmetry
# spherical_symmetry <bound method Geometry.__legacy_convert_geometryType of <magrittetorch.model.geometry.geometry.Geometry object at 0x7f75784639d0>>
# spherical_symmetry
# setting param Parameter geometryType with current value: None to value GeometryType.SpericallySymmetric1D
# setting param Parameter boundaryType with current value: None to value BoundaryType.Sphere1D
# setting param Parameter npoints with current value: None to value 10
# setting param Parameter npoints with current value: 10 to value 10
# [[<Quantity 1.e+08 1 / m3>, <Quantity 1.e+12 1 / m3>], [<Quantity 1.e+08 1 / m3>, <Quantity 1.e+12 1 / m3>], [<Quantity 1.e+08 1 / m3>, <Quantity 1.e+12 1 / m3>], [<Quantity 1.e+08 1 / m3>, <Quantity 1.e+12 1 / m3>], [<Quantity 1.e+08 1 / m3>, <Quantity 1.e+12 1 / m3>], [<Quantity 1.e+08 1 / m3>, <Quantity 1.e+12 1 / m3>], [<Quantity 1.e+08 1 / m3>, <Quantity 1.e+12 1 / m3>], [<Quantity 1.e+08 1 / m3>, <Quantity 1.e+12 1 / m3>], [<Quantity 1.e+08 1 / m3>, <Quantity 1.e+12 1 / m3>], [<Quantity 1.e+08 1 / m3>, <Quantity 1.e+12 1 / m3>]]
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter nspecs with current value: None to value 2
# setting param Parameter nspecs with current value: 2 to value 2
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter nboundary with current value: None to value 2
# setting param Parameter nboundary with current value: 2 to value 2
# setting param Parameter nboundary with current value: 2 to value 2
# setting param Parameter nboundary with current value: 2 to value 2
# nrays 10
# direction [[ 1.          0.          0.        ]
#  [ 0.92387953  0.38268343  0.        ]
#  [ 0.70710678  0.70710678  0.        ]
#  [ 0.38268343  0.92387953  0.        ]
#  [ 0.          1.          0.        ]
#  [-1.         -0.         -0.        ]
#  [-0.92387953 -0.38268343 -0.        ]
#  [-0.70710678 -0.70710678 -0.        ]
#  [-0.38268343 -0.92387953 -0.        ]
#  [-0.         -1.         -0.        ]]
# setting param Parameter nrays with current value: None to value 10
# setting param Parameter nrays with current value: 10 to value 10
# setting param Parameter nrays with current value: 10 to value 10
# setting param Parameter nlspecs with current value: None to value 1
# Parameter nlspecs with current value: 1 Delayed list of class instances: lineProducingSpecies of parameter size: Parameter nlspecs with current value: 1
# lines/lineProducingSpecies_0/linedata/num None
# lines/lineProducingSpecies_0/linedata/num
# lines/lineProducingSpecies_0/linedata/sym None
# lines/lineProducingSpecies_0/linedata/sym
# lines/lineProducingSpecies_0/linedata/nlev None
# lines/lineProducingSpecies_0/linedata/nlev
# lines/lineProducingSpecies_0/linedata/nrad None
# lines/lineProducingSpecies_0/linedata/nlev
# <function Linedata.__init__.<locals>.<lambda> at 0x7f7577dcc4a0> lines/lineProducingSpecies_0/linedata/
# lines/lineProducingSpecies_0/linedata/ <function Linedata.__init__.<locals>.<lambda> at 0x7f7577dcc4a0>
# lines/lineProducingSpecies_0/linedata/
# lines/lineProducingSpecies_0/linedata/inverse_mass None
# lines/lineProducingSpecies_0/linedata/inverse_mass
# <function LegacyHelper.read_length_of_dataset at 0x7f757ba4f7e0> lines/lineProducingSpecies_0/quadrature/weights
# lines/lineProducingSpecies_0/quadrature/weights <function LegacyHelper.read_length_of_dataset at 0x7f757ba4f7e0>
# lines/lineProducingSpecies_0/quadrature/weights
# [b'test' b'H2']
# setting param Parameter lines/lineProducingSpecies_0/linedata/sym with current value: None to value test
# setting param Parameter lines/lineProducingSpecies_0/linedata/num with current value: None to value 0
# setting param Parameter lines/lineProducingSpecies_0/linedata/inverse_mass with current value: None to value 1.0
# setting param Parameter lines/lineProducingSpecies_0/linedata/nlev with current value: None to value 2
# setting param Parameter lines/lineProducingSpecies_0/linedata/nlev with current value: 2 to value 2
# setting param Parameter lines/lineProducingSpecies_0/linedata/nlev with current value: 2 to value 2
# setting param Parameter lines/lineProducingSpecies_0/linedata/ncolpar with current value: None to value 1
# Parameter lines/lineProducingSpecies_0/linedata/ncolpar with current value: 1 Delayed list of class instances: collisionPartner of parameter size: Parameter lines/lineProducingSpecies_0/linedata/ncolpar with current value: 1
# <function LegacyHelper.read_length_of_dataset at 0x7f757ba4f7e0> lines/lineProducingSpecies_0/linedata/collisionPartner_0/tmp
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/tmp <function LegacyHelper.read_length_of_dataset at 0x7f757ba4f7e0>
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/tmp
# <function LegacyHelper.read_length_of_dataset at 0x7f757ba4f7e0> lines/lineProducingSpecies_0/linedata/collisionPartner_0/icol
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/icol <function LegacyHelper.read_length_of_dataset at 0x7f757ba4f7e0>
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/icol
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/num_col_partner None
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/num_col_partner
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/orth_or_para_H2 None
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/orth_or_para_H2
# [b'test' b'H2']
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/num_col_partner with current value: None to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/orth_or_para_H2 with current value: None to value n
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ncol with current value: None to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ntmp with current value: None to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ncol with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ncol with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ntmp with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ntmp with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ncol with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ntmp with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ncol with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: None to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/quadrature/nquads with current value: None to value 100
# setting param Parameter lines/lineProducingSpecies_0/quadrature/nquads with current value: 100 to value 100
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter nrays with current value: 10 to value 10
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter lines/lineProducingSpecies_0/linedata/nlev with current value: 2 to value 2
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter npoints with current value: 10 to value 10
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# idx 0
# idx 1
# idx 2
# idx 3
# idx 4
# idx 5
# idx 6
# idx 7
# idx 8
# idx 9
# computed mean intensity [[[3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   ...
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]]
#
#  [[3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   ...
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]]
#
#  [[3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   ...
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]]
#
#  [[3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   ...
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]]
#
#  [[3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   ...
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]
#   [3.7728626e-18 3.7728605e-18 3.7728589e-18 ... 3.7727766e-18
#    3.7727749e-18 3.7727733e-18]]] J / m2
# nu [1.79868521e+11 1.79868824e+11 1.79869073e+11 1.79869295e+11
#  1.79869500e+11 1.79869691e+11 1.79869873e+11 1.79870047e+11
#  1.79870214e+11 1.79870376e+11 1.79870534e+11 1.79870687e+11
#  1.79870837e+11 1.79870984e+11 1.79871128e+11 1.79871269e+11
#  1.79871408e+11 1.79871545e+11 1.79871680e+11 1.79871814e+11
#  1.79871946e+11 1.79872076e+11 1.79872205e+11 1.79872333e+11
#  1.79872460e+11 1.79872585e+11 1.79872710e+11 1.79872834e+11
#  1.79872956e+11 1.79873079e+11 1.79873200e+11 1.79873320e+11
#  1.79873440e+11 1.79873560e+11 1.79873679e+11 1.79873797e+11
#  1.79873915e+11 1.79874033e+11 1.79874150e+11 1.79874266e+11
#  1.79874383e+11 1.79874499e+11 1.79874615e+11 1.79874731e+11
#  1.79874846e+11 1.79874962e+11 1.79875077e+11 1.79875192e+11
#  1.79875307e+11 1.79875422e+11 1.79875537e+11 1.79875652e+11
#  1.79875767e+11 1.79875882e+11 1.79875998e+11 1.79876113e+11
#  1.79876228e+11 1.79876344e+11 1.79876460e+11 1.79876576e+11
#  1.79876693e+11 1.79876809e+11 1.79876927e+11 1.79877044e+11
#  1.79877162e+11 1.79877280e+11 1.79877399e+11 1.79877519e+11
#  1.79877639e+11 1.79877759e+11 1.79877881e+11 1.79878003e+11
#  1.79878125e+11 1.79878249e+11 1.79878374e+11 1.79878499e+11
#  1.79878626e+11 1.79878754e+11 1.79878883e+11 1.79879013e+11
#  1.79879145e+11 1.79879279e+11 1.79879414e+11 1.79879551e+11
#  1.79879690e+11 1.79879831e+11 1.79879975e+11 1.79880122e+11
#  1.79880272e+11 1.79880425e+11 1.79880583e+11 1.79880745e+11
#  1.79880912e+11 1.79881086e+11 1.79881268e+11 1.79881459e+11
#  1.79881664e+11 1.79881886e+11 1.79882135e+11 1.79882438e+11] Hz
# 6.663409675989156e-14 1 / m
# 6.663409675989156e-14 1 / m
# angles [ 0.          0.39269908  0.78539816  1.17809725  1.57079633 -3.14159265
#  -2.74889357 -2.35619449 -1.96349541 -1.57079633] rad
# 10.0
# 10
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/github/Magritte/dependencies/miniconda3/envs/magritte-torch/lib/python3.11/site-packages/astropy/units/quantity.py:1370, in Quantity.__index__(self)
#    1369 try:
# -> 1370     assert self.unit.is_unity()
#    1371     return self.value.__index__()
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /lhome/thomasc/github/Magritte-torch/tests/benchmarks/analytic/benchmarks.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/lhome/thomasc/github/Magritte-torch/tests/benchmarks/analytic/benchmarks.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from constant_velocity_gradient_1D import run_test
# ----> <a href='vscode-notebook-cell:/lhome/thomasc/github/Magritte-torch/tests/benchmarks/analytic/benchmarks.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> run_test()
#
# File ~/github/Magritte-torch/tests/benchmarks/analytic/constant_velocity_gradient_1D.py:316, in run_test(nosave)
#     314 def run_test (nosave=False):
# --> 316     create_and_run_model(nosave)
#     317     # run_model (nosave)
#     319     return
#
# File ~/github/Magritte-torch/tests/benchmarks/analytic/constant_velocity_gradient_1D.py:212, in create_and_run_model(nosave, use_widgets)
#     210 print(nrays)
#     211 angles     = angles[:nrays//2]
# --> 212 fullangles = np.concatenate(angles, angles + np.pi*units.rad)
#     214 # for f in nu:
#     215 #     for r in rs:
#     216 #         for a in angles:
#    (...)
#     219
#     220 # us = np.array([[[u_(f,r,a) for f in nu] for r in rs] for a in angles])
#     221 I_analytic = np.array([[[I_(f,r,a)/units.J*units.m**2 for f in nu] for r in rs] for a in fullangles])*units.J/units.m**2
#
# File ~/github/Magritte/dependencies/miniconda3/envs/magritte-torch/lib/python3.11/site-packages/astropy/units/quantity.py:1855, in Quantity.__array_function__(self, function, types, args, kwargs)
#    1852     except NotImplementedError:
#    1853         return self._not_implemented_or_raise(function, types)
# -> 1855     result = super().__array_function__(function, types, args, kwargs)
#    1856     # Fall through to return section
#    1858 elif function in DISPATCHED_FUNCTIONS:
#
# File ~/github/Magritte/dependencies/miniconda3/envs/magritte-torch/lib/python3.11/site-packages/astropy/units/quantity.py:1373, in Quantity.__index__(self)
#    1371     return self.value.__index__()
#    1372 except Exception:
# -> 1373     raise TypeError(
#    1374         "only integer dimensionless scalar quantities "
#    1375         "can be converted to a Python index"
#    1376     )
#
# TypeError: only integer dimensionless scalar quantities can be converted to a Python index

# %%
from all_constant_single_ray_no_saving_model import run_test
run_test()
# Out:
# npoints None
# nrays None
# nboundary None
# nspecs None
# nlspecs None
# turb 0.0 m / s
# <bound method Boundary.__legacy_convert_boundaryType of <magrittetorch.model.geometry.boundary.Boundary object at 0x7f2da9a5c990>> spherical_symmetry
# spherical_symmetry <bound method Boundary.__legacy_convert_boundaryType of <magrittetorch.model.geometry.boundary.Boundary object at 0x7f2da9a5c990>>
# spherical_symmetry
# <bound method Geometry.__legacy_convert_geometryType of <magrittetorch.model.geometry.geometry.Geometry object at 0x7f2da60f8d10>> spherical_symmetry
# spherical_symmetry <bound method Geometry.__legacy_convert_geometryType of <magrittetorch.model.geometry.geometry.Geometry object at 0x7f2da60f8d10>>
# spherical_symmetry
# setting param Parameter geometryType with current value: None to value GeometryType.General3D
# setting param Parameter boundaryType with current value: None to value BoundaryType.AxisAlignedCube
# setting param Parameter npoints with current value: None to value 50
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter nspecs with current value: None to value 3
# setting param Parameter nspecs with current value: 3 to value 3
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter nboundary with current value: None to value 2
# setting param Parameter nboundary with current value: 2 to value 2
# setting param Parameter nboundary with current value: 2 to value 2
# setting param Parameter nboundary with current value: 2 to value 2
# setting param Parameter nrays with current value: None to value 2
# setting param Parameter nrays with current value: 2 to value 2
# setting param Parameter nlspecs with current value: None to value 1
# Parameter nlspecs with current value: 1 Delayed list of class instances: lineProducingSpecies of parameter size: Parameter nlspecs with current value: 1
# lines/lineProducingSpecies_0/linedata/num None
# lines/lineProducingSpecies_0/linedata/num
# lines/lineProducingSpecies_0/linedata/sym None
# lines/lineProducingSpecies_0/linedata/sym
# lines/lineProducingSpecies_0/linedata/nlev None
# lines/lineProducingSpecies_0/linedata/nlev
# lines/lineProducingSpecies_0/linedata/nrad None
# lines/lineProducingSpecies_0/linedata/nlev
# <function Linedata.__init__.<locals>.<lambda> at 0x7f2da5b0ae80> lines/lineProducingSpecies_0/linedata/
# lines/lineProducingSpecies_0/linedata/ <function Linedata.__init__.<locals>.<lambda> at 0x7f2da5b0ae80>
# lines/lineProducingSpecies_0/linedata/
# lines/lineProducingSpecies_0/linedata/inverse_mass None
# lines/lineProducingSpecies_0/linedata/inverse_mass
# <function LegacyHelper.read_length_of_dataset at 0x7f2da9af4040> lines/lineProducingSpecies_0/quadrature/weights
# lines/lineProducingSpecies_0/quadrature/weights <function LegacyHelper.read_length_of_dataset at 0x7f2da9af4040>
# lines/lineProducingSpecies_0/quadrature/weights
# [b'test' b'H2' b'e-']
# setting param Parameter lines/lineProducingSpecies_0/linedata/sym with current value: None to value test
# setting param Parameter lines/lineProducingSpecies_0/linedata/num with current value: None to value 0
# setting param Parameter lines/lineProducingSpecies_0/linedata/inverse_mass with current value: None to value 1.0
# setting param Parameter lines/lineProducingSpecies_0/linedata/nlev with current value: None to value 2
# setting param Parameter lines/lineProducingSpecies_0/linedata/nlev with current value: 2 to value 2
# setting param Parameter lines/lineProducingSpecies_0/linedata/nlev with current value: 2 to value 2
# setting param Parameter lines/lineProducingSpecies_0/linedata/ncolpar with current value: None to value 1
# Parameter lines/lineProducingSpecies_0/linedata/ncolpar with current value: 1 Delayed list of class instances: collisionPartner of parameter size: Parameter lines/lineProducingSpecies_0/linedata/ncolpar with current value: 1
# <function LegacyHelper.read_length_of_dataset at 0x7f2da9af4040> lines/lineProducingSpecies_0/linedata/collisionPartner_0/tmp
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/tmp <function LegacyHelper.read_length_of_dataset at 0x7f2da9af4040>
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/tmp
# <function LegacyHelper.read_length_of_dataset at 0x7f2da9af4040> lines/lineProducingSpecies_0/linedata/collisionPartner_0/icol
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/icol <function LegacyHelper.read_length_of_dataset at 0x7f2da9af4040>
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/icol
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/num_col_partner None
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/num_col_partner
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/orth_or_para_H2 None
# lines/lineProducingSpecies_0/linedata/collisionPartner_0/orth_or_para_H2
# [b'test' b'H2' b'e-']
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/num_col_partner with current value: None to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/orth_or_para_H2 with current value: None to value n
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ncol with current value: None to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ntmp with current value: None to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ncol with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ncol with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ntmp with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ntmp with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ncol with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ntmp with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/collisionPartner_0/ncol with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: None to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/quadrature/nquads with current value: None to value 1
# setting param Parameter lines/lineProducingSpecies_0/quadrature/nquads with current value: 1 to value 1
# ncolpar 1
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter nrays with current value: 2 to value 2
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter lines/lineProducingSpecies_0/linedata/nlev with current value: 2 to value 2
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# setting param Parameter npoints with current value: 50 to value 50
# setting param Parameter lines/lineProducingSpecies_0/linedata/nrad with current value: 1 to value 1
# rr: 0
# rr: 1
# 1.6080215482991831e-18 1 / m
# 1.6080215482991831e-18 1 / m
# --- Benchmark name ----------------------------
# all_constant_single_ray_no_save_model
# --- Parameters --------------------------------
# dimension = 1
# npoints   = 50
# nrays     = 2
# nquads    = 1
# --- Accuracy ----------------------------------
# max error in shortchar 0 = 8.252767431725784e-09
# --- Timers ------------------------------------
# timer: setting model = 0.001711987002636306
# timer: shortchar 0   = 0.0777643210021779
# -----------------------------------------------
