# %%
from constant_velocity_gradient_1D import run_test
run_test()
# Out:
# npoints None
# nrays None
# nboundary None
# nspecs None
# nlspecs None
# <bound method Boundary.__legacy_convert_boundaryType of <magrittetorch.model.geometry.boundary.Boundary object at 0x7f7e27af4290>> spherical_symmetry
# spherical_symmetry <bound method Boundary.__legacy_convert_boundaryType of <magrittetorch.model.geometry.boundary.Boundary object at 0x7f7e27af4290>>
# spherical_symmetry
# <bound method Geometry.__legacy_convert_geometryType of <magrittetorch.model.geometry.geometry.Geometry object at 0x7f7e27afb610>> spherical_symmetry
# spherical_symmetry <bound method Geometry.__legacy_convert_geometryType of <magrittetorch.model.geometry.geometry.Geometry object at 0x7f7e27afb610>>
# spherical_symmetry
# setting param Parameter geometryType with current value: None to value GeometryType.SpericallySymmetric1D
# setting param Parameter boundaryType with current value: None to value BoundaryType.Sphere1D
# 2 2
# ...

# %%
from all_constant_single_ray_no_saving_model import run_test
run_test()
